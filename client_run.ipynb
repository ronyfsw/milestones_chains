# %% [markdown]
# # Build Chains and Results
# Instructions: https://fsworks.atlassian.net/wiki/spaces/~558841686/pages/edit-v2/2087550977

# %%
import subprocess
data_file_name = 'EMS_DCMA_DD_23.08.graphml'
experiment = None
tasks_types = 'tdas'
results = 'prt'
query = 'code' 
if not experiment: experiment = data_file_name.replace('.graphml', '').replace('.', '_')
from calculate import *
run_calculation_process(data_file_name, experiment, tasks_types, results, query)
# Out:
# Starting EC2 instance: i-0586e11281d4b02a2
# EC2 instance "i-0586e11281d4b02a2" has been started
# Data file uploaded to S3
# Calculation finished
# Compute instance stopped
# Preparing results
# chains file chains.parquet
# chains path EMS_DCMA_DD_23_08/chains.parquet
# The results have been downloaded to EMS_DCMA_DD_23_08
# 11410 chains written to chains.parquet
# 186414 tasks rows written to parquet files in the prt sub-directory

# %% [markdown]
# # Query Results

# %%
import duckdb
con = duckdb.connect()
prt_files_path = os.path.join(experiment, 'prt')
results_files = "'{e}/*.parquet'".format(e=prt_files_path)
query = """SELECT * FROM {rf} LIMIT 10""".format(rf=results_files)
query_df = con.execute(query).df()
#query_df.to_excel('query_df.xlsx')
display(query_df.head(20))
# Out:
#                    ID ChainID TaskID         NeighbourID Dependency  \
# 0   MI20-EMS-N2-60000      C1   C1T1  MI20-EMS-N2-111010         FS
# 1  MI20-EMS-N2-111010      C1   C1T2  MI20-EMS-N2-111020         FS
# 2  MI20-EMS-N2-111020      C1   C1T3  MI20-EMS-N2-111060         FS
# 3  MI20-EMS-N2-111060      C1   C1T4  MI20-EMS-N2-111070         FS
# 4  MI20-EMS-N2-111070      C1   C1T5   MI20-EMS-N2-61080         FS
# 5   MI20-EMS-N2-61080      C1   C1T6   MI20-EMS-N2-61090         FS
# 6   MI20-EMS-N2-61090      C1   C1T7   MI20-EMS-N2-61110         FS
# 7   MI20-EMS-N2-61110      C1   C1T8   MI20-EMS-N2-61130         FS
# 8   MI20-EMS-N2-61130      C1   C1T9   MI20-EMS-N2-61150         FS
# 9   MI20-EMS-N2-61150      C1  C1T10  MI20-EMS-N2-120958         FS
#
#      TaskType                                               Label  \
# 0  TT_FinMile                                   JS0 - T0 TF - NTP
# 1     TT_Task    Activits SDR System (portes voyageur) [ex-CDR S]
# 2  TT_FinMile       OIM - SDR System (portes voyageur) [ex-CDR S]
# 3     TT_Task                                 Activits IDR System
# 4  TT_FinMile                                    OIM - IDR System
# 5  TT_FinMile               OIM - IDRs - Interface Gate [TRAIN 1]
# 6     TT_Mile               IIM - IGR - Interface Gate - OFFICIEL
# 7     TT_Mile             IIM - PGR - Preliminary Gate - OFFICIEL
# 8     TT_Mile  IIM - CGR 1st - 1st Train Critical Gate - OFFICIEL
# 9     TT_Mile      IIM - CGR Full - Full Critical Gate - OFFICIEL
#
#   PlannedStart  PlannedEnd ActualStart   ActualEnd Float1       Status  \
# 0   2021-06-30  2021-06-30  2021-06-30  2021-06-30      0  TK_Complete
# 1   2021-01-07  2021-01-07  2021-01-07  2022-05-31      0  TK_Complete
# 2   2022-05-31  2022-05-31  2022-05-31  2022-05-31      0  TK_Complete
# 3   2022-06-30  2022-06-30  2022-01-06         nan      0    TK_Active
# 4   2022-05-10  2022-05-10         nan         nan      0  TK_NotStart
# 5   2023-02-01  2023-02-01         nan         nan      0  TK_NotStart
# 6   2022-10-27  2022-10-27         nan         nan      0  TK_NotStart
# 7   2023-07-04  2023-07-04         nan         nan      0  TK_NotStart
# 8   2023-07-07  2023-07-07         nan         nan      0  TK_NotStart
# 9   2023-08-08  2023-08-08         nan         nan      0  TK_NotStart
#
#                         File planned_duration actual_duration
# 0  EMS_DCMA_DD_23.08.graphml                0             0.0
# 1  EMS_DCMA_DD_23.08.graphml                0           334.0
# 2  EMS_DCMA_DD_23.08.graphml                0             0.0
# 3  EMS_DCMA_DD_23.08.graphml                0             nan
# 4  EMS_DCMA_DD_23.08.graphml                0             nan
# 5  EMS_DCMA_DD_23.08.graphml                0             nan
# 6  EMS_DCMA_DD_23.08.graphml                0             nan
# 7  EMS_DCMA_DD_23.08.graphml                0             nan
# 8  EMS_DCMA_DD_23.08.graphml                0             nan
# 9  EMS_DCMA_DD_23.08.graphml                0             nan

# %% [markdown]
# # Read Chains

# %%
chains_path = os.path.join(experiment, 'chains.parquet')
chains_df = pd.read_parquet(chains_path)
chains = list(chains_df['Chain'])
chains = '\n'.join(chains)+'\n'
with open('chains.txt', 'w') as f: f.write(chains)

# %%
display(chains_df.head())
# Out:
#   Chain_ID  \
# 0       C1
# 1       C2
# 2       C3
# 3       C4
# 4       C5
#
#                                                                                                  Chain
# 0  MI20-EMS-N2-60000<>MI20-EMS-N2-111010<>MI20-EMS-N2-111020<>MI20-EMS-N2-111060<>MI20-EMS-N2-11107...
# 1  MI20-EMS-N2-60000<>MI20-EMS-N2-108420<>MI20-EMS-N2-108430<>MI20-EMS-N2-61064<>MI20-EMS-N2-61073<...
# 2  MI20-EMS-N2-60000<>MI20-EMS-N2-117900<>MI20-EMS-N2-117910<>MI20-EMS-N2-117940<>MI20-EMS-N2-11795...
# 3  MI20-EMS-N2-60000<>MI20-EMS-N2-111022<>MI20-EMS-N2-111024<>MI20-EMS-N2-111060<>MI20-EMS-N2-11107...
# 4  MI20-EMS-N2-60000<>MI20-EMS-N2-98790<>MI20-EMS-N2-98800<>MI20-EMS-N2-98810<>MI20-EMS-N2-98820<>M...
